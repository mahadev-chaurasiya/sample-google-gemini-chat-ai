# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os
load_dotenv()
key = os.getenv("GEMINI_API_KEY")

genai.configure(api_key=key)
print(key)
# Out:
# AIzaSyD6hvIJWvXafx6W6ZKu52HpnOdey3zSe68

# %%
model = genai.GenerativeModel('gemini-2.5-flash')
response = model.generate_content("who is Sardar ballav bhai patel?")
print(response.text)
# Out:
# You've spelled it "Ballav," but the correct spelling is **Sardar Vallabhbhai Patel**.
#
# Sardar Vallabhbhai Patel was a pivotal figure in India's struggle for independence and, even more critically, in its post-independence consolidation. He is widely known as the **"Iron Man of India"** and is often compared to Otto von Bismarck for his role in uniting a fragmented nation.
#
# Here's a breakdown of who he was:
#
# 1.  **Early Life and Legal Career:** Born in Nadiad, Gujarat, in 1875, Vallabhbhai Patel trained as a lawyer and established a successful practice before being drawn into the freedom movement.
#
# 2.  **Role in the Freedom Struggle:**
#     *   He became a staunch follower of Mahatma Gandhi and one of his closest lieutenants.
#     *   He played a crucial role in various satyagrahas (non-violent resistance movements), including the **Kheda Satyagraha (1918)** and particularly the **Bardoli Satyagraha (1928)**. It was during the Bardoli Satyagraha, a farmers' protest against oppressive taxes, that the peasants bestowed upon him the honorific title **"Sardar"** (meaning chief or leader).
#     *   He was imprisoned multiple times for his participation in the Non-Cooperation Movement, Salt Satyagraha, and the Quit India Movement.
#
# 3.  **Post-Independence: The Architect of Modern India:**
#     *   This is arguably his most significant contribution. After India gained independence in 1947, he became India's **first Deputy Prime Minister and first Home Minister.**
#     *   His monumental task was the **integration of over 560 princely states** (which had been semi-autonomous under British rule) into the Indian Union. Using a combination of diplomacy, persuasion, and, when necessary, firm action (as in the cases of Hyderabad, Junagadh, and Kashmir), he successfully merged these states, preventing the Balkanization of India and laying the geographical and political foundation for the modern nation.
#     *   He was a pragmatist and a strong administrator, focused on maintaining law and order and building a unified national identity.
#
# 4.  **Legacy:**
#     *   His unwavering resolve and strategic vision in integrating the princely states earned him the title "Iron Man of India."
#     *   He is revered as one of the true founding fathers of the Republic of India.
#     *   His legacy is honored with the **"Statue of Unity"** in Gujarat, the world's tallest statue, dedicated to him.
#
# In essence, Sardar Vallabhbhai Patel was an indispensable leader whose strategic thinking and unwavering determination cemented India's territorial integrity, shaping the unified nation we know today.
